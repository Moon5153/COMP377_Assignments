# %%
#import librarires
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn import linear_model
from sklearn.neural_network import MLPClassifier

# %%
#Reading dataset
df = pd.read_csv('student.cleaned.data.csv')
df
# Out:
#     school gender  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0       GP      F   18       U     GT3       A     4     4   at_home
# 1       GP      F   17       U     GT3       T     1     1   at_home
# 2       GP      F   15       U     LE3       T     1     1   at_home
# 3       GP      F   15       U     GT3       T     4     2    health
# 4       GP      F   16       U     GT3       T     3     3     other
# ..     ...    ...  ...     ...     ...     ...   ...   ...       ...
# 390     MS      M   20       U     LE3       A     2     2  services
# 391     MS      M   17       U     LE3       T     3     1  services
# 392     MS      M   21       R     GT3       T     1     1     other
# 393     MS      M   18       R     LE3       T     3     2  services
# 394     MS      M   19       U     LE3       T     1     1     other
#
#          Fjob  ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  \
# ...

# %%
#Taking the features into account (traveltime, studytime, failures, famrel, freetime, goout, health)
X = df[['traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout', 'health']]

# %%
y = np.where(df['G3'] < 10, 0, 1)

# %%
#Initialize Logistic regression model
logistic=linear_model.LogisticRegression()
#Fitting the data
logistic.fit(X,y)
# Out:
# LogisticRegression()

# %%
#Initialize MLPClassifier
mlp=MLPClassifier(max_iter=300, random_state=1)
#Fitting the data
mlp.fit(X,y)
# Out:
# C:\Users\Moon\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier()

# %%
#Evaluate Accuracy of Logisitic Model
score=logistic.score(X,y)
print('Accuracy of Logistic Model: ',score)
# Out:
# Accuracy of Logistic Model:  0.7316455696202532

# %%
#Evaluate Accuracy of Model using MLP
score2=mlp.score(X,y)
print('Accuracy of Model using MLP classifier: ',score2)
# Out:
# Accuracy of Model using MLP classifier:  0.7468354430379747

# %%
#Here the accuracy score computed for MLP classifier is a little higher than the logistic model.This can conclude 
#MLP classifier here provides better performance than Logisitic
